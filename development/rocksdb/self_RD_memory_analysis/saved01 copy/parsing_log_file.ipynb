# %% [markdown]
# ### Parsing the full log data to structure it with file names as Y-axis and categories as X-axis

# %%
import pandas as pd

# %%
full_log_entries = """
log4111:insertion_time_ns = 29666617756
log4111:rd_time_ns = 6192352
log4111:total_cpu_time_ns = 5996000.00
log4111:whole block total_cpu_time_ns = 12997000.00
log4111:fixed #PQ = 5000 point_query_time_on_existing_keys_ns = 13934640549
log4111:fixed #PQ = 5000 point_query_time_on_currently_deleted_all_ns = 9800102246
log4111:all_time_ns = 462922168219
log4211:insertion_time_ns = 26830023324
log4211:rd_time_ns = 6026404
log4211:total_cpu_time_ns = 7000000.00
log4211:whole block total_cpu_time_ns = 12999000.00
log4211:fixed #PQ = 5000 point_query_time_on_existing_keys_ns = 10959277743
log4211:fixed #PQ = 5000 point_query_time_on_currently_deleted_all_ns = 7208401746
log4211:all_time_ns = 463152179840
log4311:insertion_time_ns = 28067341363
log4311:rd_time_ns = 5952320
log4311:total_cpu_time_ns = 4001000.00
log4311:whole block total_cpu_time_ns = 12999000.00
log4311:fixed #PQ = 5000 point_query_time_on_existing_keys_ns = 10927094336
log4311:fixed #PQ = 5000 point_query_time_on_currently_deleted_all_ns = 4263221367
log4311:all_time_ns = 449622760500
log4411:insertion_time_ns = 28208421394
log4411:rd_time_ns = 6204361
log4411:total_cpu_time_ns = 7000000.00
log4411:whole block total_cpu_time_ns = 12999000.00
log4411:fixed #PQ = 5000 point_query_time_on_existing_keys_ns = 10972642225
log4411:fixed #PQ = 5000 point_query_time_on_currently_deleted_all_ns = 35041626
log4411:all_time_ns = 443964468937
log4511:insertion_time_ns = 28889529765
log4511:rd_time_ns = 5667715
log4511:total_cpu_time_ns = 5998000.00
log4511:whole block total_cpu_time_ns = 11998000.00
log4511:fixed #PQ = 5000 point_query_time_on_existing_keys_ns = 11199525573
log4511:fixed #PQ = 5000 point_query_time_on_currently_deleted_all_ns = 7354370171
log4511:all_time_ns = 451485703088
log4611:insertion_time_ns = 28818791334
log4611:rd_time_ns = 5157282
log4611:total_cpu_time_ns = 4999000.00
log4611:whole block total_cpu_time_ns = 12999000.00
log4611:fixed #PQ = 5000 point_query_time_on_existing_keys_ns = 11128379953
log4611:fixed #PQ = 5000 point_query_time_on_currently_deleted_all_ns = 4778582184
log4611:all_time_ns = 445898094976
log4711:insertion_time_ns = 28983600701
log4711:rd_time_ns = 6117240
log4711:total_cpu_time_ns = 6001000.00
log4711:whole block total_cpu_time_ns = 12998000.00
log4711:fixed #PQ = 5000 point_query_time_on_existing_keys_ns = 11274613196
log4711:fixed #PQ = 5000 point_query_time_on_currently_deleted_all_ns = 7445461927
log4711:all_time_ns = 453037378425
log4811:insertion_time_ns = 28663869656
log4811:rd_time_ns = 6268179
log4811:total_cpu_time_ns = 7999000.00
log4811:whole block total_cpu_time_ns = 12999000.00
log4811:fixed #PQ = 5000 point_query_time_on_existing_keys_ns = 11258363479
log4811:fixed #PQ = 5000 point_query_time_on_currently_deleted_all_ns = 5611498223
log4811:all_time_ns = 449307771477
log4911:insertion_time_ns = 29423079110
log4911:rd_time_ns = 5449316
log4911:total_cpu_time_ns = 4000000.00
log4911:whole block total_cpu_time_ns = 11999000.00
log4911:fixed #PQ = 5000 point_query_time_on_existing_keys_ns = 11149016515
log4911:fixed #PQ = 5000 point_query_time_on_currently_deleted_all_ns = 7370073507
log4911:all_time_ns = 450923102871
log5011:insertion_time_ns = 27048318887
log5011:rd_time_ns = 6120011
log5011:total_cpu_time_ns = 2000000.00
log5011:whole block total_cpu_time_ns = 13999000.00
log5011:fixed #PQ = 5000 point_query_time_on_existing_keys_ns = 11256267520
log5011:fixed #PQ = 5000 point_query_time_on_currently_deleted_all_ns = 5973341813
log5011:all_time_ns = 455424732572
log5111:insertion_time_ns = 29328439272
log5111:rd_time_ns = 5725660
log5111:total_cpu_time_ns = 6999000.00
log5111:whole block total_cpu_time_ns = 13998000.00
log5111:fixed #PQ = 5000 point_query_time_on_existing_keys_ns = 11321839652
log5111:fixed #PQ = 5000 point_query_time_on_currently_deleted_all_ns = 7468998951
log5111:all_time_ns = 452181861365
log5211:insertion_time_ns = 28417484109
log5211:rd_time_ns = 6208722
log5211:total_cpu_time_ns = 4001000.00
log5211:whole block total_cpu_time_ns = 12999000.00
log5211:fixed #PQ = 5000 point_query_time_on_existing_keys_ns = 11464274073
log5211:fixed #PQ = 5000 point_query_time_on_currently_deleted_all_ns = 4913737121
log5211:all_time_ns = 449723303649
log5311:insertion_time_ns = 28637073785
log5311:rd_time_ns = 5581048
log5311:total_cpu_time_ns = 7999000.00
log5311:whole block total_cpu_time_ns = 12999000.00
log5311:fixed #PQ = 5000 point_query_time_on_existing_keys_ns = 11246413156
log5311:fixed #PQ = 5000 point_query_time_on_currently_deleted_all_ns = 7351730870
log5311:all_time_ns = 451089896325
log5411:insertion_time_ns = 29338691495
log5411:rd_time_ns = 6247087
log5411:total_cpu_time_ns = 3998000.00
log5411:whole block total_cpu_time_ns = 12999000.00
log5411:fixed #PQ = 5000 point_query_time_on_existing_keys_ns = 11376472270
log5411:fixed #PQ = 5000 point_query_time_on_currently_deleted_all_ns = 4898831219
log5411:all_time_ns = 447227744055
log5511:insertion_time_ns = 27750001808
log5511:rd_time_ns = 4386097
log5511:total_cpu_time_ns = 7001000.00
log5511:whole block total_cpu_time_ns = 12999000.00
log5511:fixed #PQ = 5000 point_query_time_on_existing_keys_ns = 11174284838
log5511:fixed #PQ = 5000 point_query_time_on_currently_deleted_all_ns = 7356350466
log5511:all_time_ns = 455925783480
log5611:insertion_time_ns = 27951578629
log5611:rd_time_ns = 5850928
log5611:total_cpu_time_ns = 2000000.00
log5611:whole block total_cpu_time_ns = 12999000.00
log5611:fixed #PQ = 5000 point_query_time_on_existing_keys_ns = 11336749429
log5611:fixed #PQ = 5000 point_query_time_on_currently_deleted_all_ns = 4921762605
log5611:all_time_ns = 447908018402
"""

# %%
# Creating a dictionary to store structured data
structured_data = {}

# Process each log entry
for line in full_log_entries.strip().split("\n"):
    parts = line.split(" = ")
    if len(parts) == 2:
        log_id, metric = parts[0].split(":", 1)
        value = float(parts[1]) if "." in parts[1] else int(parts[1])
        
        if log_id not in structured_data:
            structured_data[log_id] = {}
        
        structured_data[log_id][metric] = value
    
    if len(parts) == 3:
        log_id, metric_1 = parts[0].split(":", 1)
        metric = metric_1 + " = " + parts[1]
        # print(log_id, metric)
        value = float(parts[2]) if "." in parts[2] else int(parts[2])
        
        if log_id not in structured_data:
            structured_data[log_id] = {}
        
        structured_data[log_id][metric] = value

# %%
# Define the required order based on the 4-digit prefix after "log"
required_order = [11, 21, 31, 41, 51, 61, 71, 81, 111, 121, 131, 141, 91, 101, 151, 161]
offset = 4000
n_group = 3

# print(str(list(structured_data.keys())))
filenames = list(structured_data.keys())

# Reinitialize a dictionary for ordered storage based on the correct mapping
sorted_filenames_corrected = {key: [] for key in required_order}

# Process each filename and categorize based on the given order
for filename in filenames:
    # num_part = (int(filename[3:7]) % 10)
    num_part = (int(filename[3:7]) - offset) // 100 * 10 + (int(filename[3:7]) % 100) // 10
    if num_part in sorted_filenames_corrected:
        sorted_filenames_corrected[num_part].append(filename)

# sorted_filenames_corrected = 
file_names_list_2d = [list(val) for val in sorted_filenames_corrected.values()]
file_names_list_2d = list(zip(*file_names_list_2d))  # Correct transposition



print(file_names_list_2d)
# # Ensure ordering is correct by maintaining the specified order
# df_sorted_filenames = pd.DataFrame.from_dict(sorted_filenames_corrected, orient="index").T

# # Display the corrected sorted groups
# tools.display_dataframe_to_user(name="Reordered Log Groups (Final)", dataframe=df_sorted_filenames)
# Out:
# [('log4111', 'log4211', 'log4311', 'log4411', 'log4511', 'log4611', 'log4711', 'log4811', 'log5111', 'log5211', 'log5311', 'log5411', 'log4911', 'log5011', 'log5511', 'log5611')]

# %%
# Convert dictionary to DataFrame
df_structured = pd.DataFrame.from_dict(structured_data, orient="index")

# Reset index and rename columns
df_structured.reset_index(inplace=True)
df_structured.rename(columns={"index": "File Name"}, inplace=True)



print(df_structured["File Name"])
# Out:
# 0     log4111
# 1     log4211
# 2     log4311
# 3     log4411
# 4     log4511
# 5     log4611
# 6     log4711
# 7     log4811
# 8     log4911
# 9     log5011
# 10    log5111
# 11    log5211
# 12    log5311
# 13    log5411
# 14    log5511
# 15    log5611
# Name: File Name, dtype: object

# %%
# # Initialize a dictionary to store the new structured data
# new_df_table = {}

# # Iterate through each group ID in sorted order
# for file_group in file_names_list_2d:
#     for log_id in file_group:
#         # Extract the corresponding row from df_structured
#         line = df_structured[df_structured["File Name"] == log_id]
#         # print(log_id)
#         # Store it in the new table
#         new_df_table[log_id] = line

# # Convert dictionary to a structured DataFrame
# df_new_table = pd.concat(new_df_table.values())
df_new_table = df_structured

# Save the new structured table
structured_table_path = "./structured_log_data.xlsx"
df_new_table.to_excel(structured_table_path, index=False)

print(df_new_table)
# # Provide download link
# structured_table_path
# Out:
#    File Name  insertion_time_ns  rd_time_ns  total_cpu_time_ns
# 0    log4111        29666617756     6192352          5996000.0  \
# 1    log4211        26830023324     6026404          7000000.0
# 2    log4311        28067341363     5952320          4001000.0
# 3    log4411        28208421394     6204361          7000000.0
# 4    log4511        28889529765     5667715          5998000.0
# 5    log4611        28818791334     5157282          4999000.0
# 6    log4711        28983600701     6117240          6001000.0
# 7    log4811        28663869656     6268179          7999000.0
# 8    log4911        29423079110     5449316          4000000.0
# 9    log5011        27048318887     6120011          2000000.0
# 10   log5111        29328439272     5725660          6999000.0
# 11   log5211        28417484109     6208722          4001000.0
# 12   log5311        28637073785     5581048          7999000.0
# 13   log5411        29338691495     6247087          3998000.0
# ...

# %%
# display(df_structured)

# # Save structured data to Excel
# #structured_excel_filename = "/mnt/data/structured_log_data.xlsx"
# structured_excel_filename = "./structured_log_data.xlsx"
# # structured_excel_filename = "./structured_log_data.csv"
# df_structured.to_excel(structured_excel_filename, index=False)

# ## Provide download link
# #structured_excel_filename
